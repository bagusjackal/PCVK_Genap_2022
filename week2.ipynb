# %% [markdown]
# <a href="https://colab.research.google.com/github/bagusjackal/PCVK_Genap_2022/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

#Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Polinema/PCVK2022/kitten01.jpg')
plt.imshow(img) # perhatikan hasilnya adalah citra dengan channel warna BGR

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) # konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/Polinema/PCVK2022/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

# simpan file image
# cv.imwrite('/content/drive/MyDrive/pcvk/img/mandrill2.tiff',img5)

# tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10)) # ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
# perhatikan koordinat titik" pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(400,400),radius=50,color=(255,0,0),thickness=-1)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
#Black Image 32
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
#Black Image 16
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],
                     [200,200],
                     [400,300],
                     [200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
Tugas

# %%
# 1. Tampilkan image dalam channel Red-Green dan Green-Blue saja!

# Red-Green
img_rg = cv.imread('/content/drive/MyDrive/Polinema/PCVK2022/kitten01.jpg',cv.IMREAD_GRAYSCALE)
plt.imshow(img_rg, cmap='RdYlGn'),plt.title("Red-Green")
#plt.imshow(img5)

# Green-Blue
img_rg = cv.imread('/content/drive/MyDrive/Polinema/PCVK2022/kitten01.jpg',cv.IMREAD_GRAYSCALE)
#img_rg [:,:,2] = 0
plt.imshow(img_rg)

# Green-Blue
img_gb = img
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %%
# 2. Tampilkan image baris ke 10-100, kolom 10-100!
img_k = img[10:100,10:100]
plt.imshow(img_k)

# %%
# 3. Tampilkan image baris ke 5-30, semua kolom, channel Green saja!
# Channel Green
img_tg3 = cv.imread('/content/drive/MyDrive/Polinema/PCVK2022/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_tg3[5:30], cmap='Greens')

# %%
# 4. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!
img_ktk = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_ktk, pt1=(300,300), pt2=(40,170), color=(0,255,255), thickness=10)
cv.rectangle(img_ktk, pt1=(900,100), pt2=(700,200), color=(0,255,0),thickness=10)
cv.rectangle(img_ktk, pt1=(400,400), pt2=(900,300), color=(255,255,255),thickness=10)
cv.rectangle(img_ktk, pt1=(100,900), pt2=(300,400), color=(255,0,0),thickness=10)
cv.rectangle(img_ktk, pt1=(900,700), pt2=(600,550), color=(0,0,255),thickness=10)
plt.imshow(img_ktk)

# %%
# 5. Tampilkan image dengan posisi terbalik!
img_t = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)
ax.imshow(img_t)

# %%
# Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :
# 6. Buat rectangle dan circle pada bagian wajah dari image kitten!
img_f = cv.imread('/content/drive/MyDrive/Polinema/PCVK2022/kitten01.jpg')
plt.imshow(img_f)

# %%
img_f = cv.imread('/content/drive/MyDrive/Polinema/PCVK2022/kitten01.jpg')
plt.imshow(img_f)
cv.rectangle(img_f,pt1=(200,360),pt2=(500,150),color=(0,0,255),thickness=15)
plt.imshow(img_f)

# %%
cv.circle(img_f,center=(350,260),radius=100,color=(255,0,0),thickness=8)
plt.imshow(img_f)

# %%
# 7. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten01.jpg!
img_f = cv.imread('/content/drive/MyDrive/Polinema/PCVK2022/kitten01.jpg')
img3 = cv.cvtColor(img_f,cv.COLOR_BGR2RGB)
cv.rectangle(img3,pt1=(100,500),pt2=(0,600),color=(0,0,255),thickness=15)
plt.imshow(img3)
